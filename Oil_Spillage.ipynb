# %% [markdown]
# <a href="https://colab.research.google.com/github/evilridersatz/test/blob/main/Oil_Spillage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.1/617.1 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tOgL1FzntFH3qOx63co0")
project = rf.workspace("achraf-baya-chatti-tf4mp").project("oil-detector")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
# ...

# %%
# !unzip '/content/drive/MyDrive/dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/train/labels/28_jpg.rf.d718ce7d1354960584c0743137ffbb3b.txt
#   inflating: __MACOSX/dataset/train/labels/._28_jpg.rf.d718ce7d1354960584c0743137ffbb3b.txt
#   inflating: dataset/train/labels/Nissan41_png_jpg.rf.24b559312185d1ff868efbfe8a03ab2a.txt
#   inflating: __MACOSX/dataset/train/labels/._Nissan41_png_jpg.rf.24b559312185d1ff868efbfe8a03ab2a.txt
#   inflating: dataset/train/labels/images161_jpg.rf.2f7a8390a3816dec7b4c5ab4c2adf9c6.txt
#   inflating: __MACOSX/dataset/train/labels/._images161_jpg.rf.2f7a8390a3816dec7b4c5ab4c2adf9c6.txt
#   inflating: dataset/train/labels/Toyota40_png_jpg.rf.6dfd07468524f9f07e1f8e041b647587.txt
#   inflating: __MACOSX/dataset/train/labels/._Toyota40_png_jpg.rf.6dfd07468524f9f07e1f8e041b647587.txt
#   inflating: dataset/train/labels/vw99_jpg.rf.1f7e3b2d6e7a7b356c53079767462d36.txt
#   inflating: __MACOSX/dataset/train/labels/._vw99_jpg.rf.1f7e3b2d6e7a7b356c53079767462d36.txt
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 79.5MB/s]

# %%
results = model.train(data='/content/Oil-Detector-1/data.yaml', epochs=50, imgsz=640, device=0)
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/Oil-Detector-1/train/images/1.jpg
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/Oil-Detector-1/train/images/1.jpg: 640x640 2 Oils, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 131.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from PIL import Image

# %%
from IPython.display import Image, display

# Replace 'result1.jpg' with the actual filename of your result image
image_path = '/content/runs/detect/predict/1.jpg'
display(Image(image_path))
