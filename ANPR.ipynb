# %% [markdown]
# <a href="https://colab.research.google.com/github/evilridersatz/test/blob/main/ANPR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.1/617.1 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/dataset (1).zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/train/labels/Cars321_png_jpg.rf.31c1c3eb084f71694dbfb7c58e672f42.txt
#   inflating: __MACOSX/dataset/train/labels/._Cars321_png_jpg.rf.31c1c3eb084f71694dbfb7c58e672f42.txt
#   inflating: dataset/train/labels/2xzi19udwjba1_jpg.rf.68bd8442aec1c89410e59c4872fa89e4.txt
#   inflating: __MACOSX/dataset/train/labels/._2xzi19udwjba1_jpg.rf.68bd8442aec1c89410e59c4872fa89e4.txt
#   inflating: dataset/train/labels/130_0050_jpg.rf.e076907a343e525c0d13b6da9f14caf8.txt
#   inflating: __MACOSX/dataset/train/labels/._130_0050_jpg.rf.e076907a343e525c0d13b6da9f14caf8.txt
#   inflating: dataset/train/labels/Cars352_png_jpg.rf.3b4f65732746bc78257b396ff5573ba2.txt
#   inflating: __MACOSX/dataset/train/labels/._Cars352_png_jpg.rf.3b4f65732746bc78257b396ff5573ba2.txt
#   inflating: dataset/train/labels/130_0031_jpg.rf.b90faab7a51125f849aedcbbaaf9e259.txt
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 173MB/s]

# %%
results = model.train(data='/content/dataset/data.yaml', epochs=50, imgsz=640, device=0)
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/dataset/1.jpg
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/dataset/1.jpg: 640x640 1 License-Plate, 15.8ms
# Speed: 2.7ms preprocess, 15.8ms inference, 240.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from PIL import Image

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/dataset/2.jpg
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/dataset/2.jpg: 640x640 1 License-Plate, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 117.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display

# Replace 'result1.jpg' with the actual filename of your result image
image_path = '/content/runs/detect/predict/1.jpg'
display(Image(image_path))

# %%
from IPython.display import Image, display

# Replace 'result1.jpg' with the actual filename of your result image
image_path = '/content/runs/detect/predict2/2.jpg'
display(Image(image_path))
